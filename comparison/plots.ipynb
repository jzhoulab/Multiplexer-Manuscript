# %%
import argparse
import math
import pyfasta
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import h5py
import random
import seaborn
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
x = "as"
torch.save(x, "train/newsa/new_file_test", create_dir = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10852/2967229604.py in <module>
#       1 x = "as"
# ----> 2 torch.save(x, "train/newsa/new_file_test", create_dir = True)
#
# TypeError: save() got an unexpected keyword argument 'create_dir'

# %%
plt.figure(figsize = (2,3))
plt.bar(["Conv + Unet + Position Encoding", "Conv + Position Encoding","Conv + Unet", "Conv"], [ 0.8429, 0.755, 0.774, 0.71], color = ["black","gray", "gray", "gray"] )
plt.xticks(rotation=45)
plt.title("Correlation by Model")
plt.xlabel("Model Architecture")
plt.ylabel("Correlation")
plt.savefig('Correlation.pdf', bbox_inches = 'tight')  
plt.yticks([i*0.1 for i in range(10)])
plt.figure()

# %%
plt.figure(figsize = (2,3))
plt.bar(["Multiplexer (position-specific)", "Multiplexer (mutation-specific)"], [ 0.86, 0.843], color = ["black","gray"] )
plt.xticks(rotation=45)
plt.title("Per-position averaged mutation effect prediction")
plt.xlabel("Model Architecture")
plt.ylabel("Correlation")
plt.yticks([i*0.1 for i in range(10)])
plt.savefig('suppfig2.pdf', bbox_inches = 'tight')

# %%
plt.figure(figsize = (2,3))
plt.bar(["Multiplexer (mutation-specific)", "Multiplexer (position-specific)"], [ 0.84, 0.77], color = ["black","gray"] )
plt.xticks(rotation=45)
plt.title("Individual mutation effects prediction")
plt.xlabel("Model Architecture")
plt.ylabel("Correlation")
plt.yticks([i*0.1 for i in range(10)])
plt.savefig('suppfig2p2.pdf', bbox_inches = 'tight')
