# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (2,3))
plt.bar(["Beluga", "Multiplexer (mutation-specific)", "Multiplexer (position-specific)"], [ 54947, 811, 426], color = ["gray","black", "black"] )
plt.xticks(rotation=45)
plt.title("Average Prediction Time - 64 Samples")
plt.ylabel("Milliseconds")

plt.savefig('speedplot.pdf', bbox_inches = 'tight')
